# %%
import pandas as pd
from pandas import DataFrame as DataFrame
from xlrd import open_workbook
import numpy as np
import re
import xlrd

def df_2_model(db_name,tbl_name,df,sheet):
    print("---------------",db_name,tbl_name,df,sheet)
    cell_name = sheet.cell_value(0,1)
    pattern = re.compile(r".*\((.*?)\).*")


    new_tbl_name = ""
    ss = cell_name.split("_")
    for s in ss:
        new_tbl_name +=s.capitalize()

    model_str= "class {}(models.Model):\n".format(new_tbl_name)
    for r in df.values:
        print(r)
        try:
#             if r[0].lower()=="id":
#                 type_str = "models.IntegerField(null=True)"
            if r[2].lower().strip()=="int":
                type_str = "models.IntegerField(null=True)"

            elif r[2].lower().strip()=="bigint":   
                type_str = "models.BigIntegerField(null=True)"

            elif r[2].lower().find("datetime")!=-1:   
                type_str = "models.DateTimeField(null=True)"

            elif r[2].lower().find("varchar")!=-1:
                line_list = r[2].lower().split('(')[1][0:-1]
                varchar_len = int(line_list)  
                type_str = "models.CharField(max_length={},null=True)".format(varchar_len)

            elif r[2].lower().strip()=="float":   
                type_str = "models.FloatField(null=True)"            

            elif r[2].lower().find("smallint")!=-1 or r[2].lower().find("tinyint")!=-1:   
                type_str = "models.SmallIntegerField(null=True)"          

            elif r[2].lower().find("text")!=-1:
                type_str = "models.TextField(null=True)"

            else:
                print("Error:{}".format(r))

            model_str += "    {} = {}\n".format(r[0].lower(),type_str)
            
        except Exception as e:
            print("Exception:{},{}\n{}".format(new_tbl_name,r,e))

    model_str += "\n    class Meta:\n        db_table = '{}'\n\n".format(cell_name)
    return model_str

def excel_2_model(db_name,excel_file,sheet_list=[]):
    newexcel = xlrd.open_workbook(excel_file)
    if sheet_list==[]:
        sheet_list=open_workbook(excel_file).sheet_names()
    rettxt = ""
    for sheetname in sheet_list:
        if sheetname.find("版本")==0 or sheetname.find("概述")==0:
            continue
        sheet = newexcel.sheet_by_name(sheetname)
        df = pd.read_excel(excel_file,sheetname,usecols=[1,2,3,4],skiprows=[0,1,2,3,4,5,6])
        rettxt = rettxt + df_2_model(db_name,sheetname,df,sheet)
    return rettxt

# %%
db_name = "pig"
excel_file = r"D:\mywork\pig\doc\数据字典\天鹏项目_数据字典v1.1.xlsx"
sheet_list = "".split(",")
txt = excel_2_model(db_name,excel_file)
print(txt)
# Out:
# ['id' '自增id' 'int' '主键,自增长']
# ['start_time' '开始时间' 'varchar(50)' '格式: YYYY-MM-DD hh:mm:ss ,联合索引']
# 00000000000000000 50
# ['device_id' '设备id' 'int' '联合索引']
# ['lng' '当前经度' 'double' nan]
# Error:['lng' '当前经度' 'double' nan]
# ['lat' '当前维度' 'double' nan]
# Error:['lat' '当前维度' 'double' nan]
# ['warn_info' '告警信息' 'longtext' '如果有告警，提供告警信息']
# ['id' '自增id' 'int' '主键,自增长']
# ['start_date' '开始时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['table_name' '表名' 'varchar(50)' '界面使用的表名']
# 00000000000000000 50
# ['id' '自增id' 'int' '主键,自增长']
# ['device_id' '设备id' 'int' nan]
# ['lng' '当前经度' 'double' nan]
# Error:['lng' '当前经度' 'double' nan]
# ['lat' '当前维度' 'double' nan]
# Error:['lat' '当前维度' 'double' nan]
# ['warn_info' '告警信息' 'longtext' '如果有告警，提供告警信息']
# ['id' '自增id' 'int' '主键,自增长']
# ['device_id' '设备id' 'int' nan]
# ['lng' '当前经度' 'double' nan]
# Error:['lng' '当前经度' 'double' nan]
# ['lat' '当前维度' 'double' nan]
# Error:['lat' '当前维度' 'double' nan]
# ['warn_info' '告警信息' 'longtext' '如果有告警，提供告警信息']
# ['id' '自增id' 'int' '主键,自增长']
# ['circle_name' '告警圈名称' 'varchar(50)' nan]
# 00000000000000000 50
# ['circle_points' '告警圈经纬度点集合' 'longtext'
#  '格式：lng,lat;lng,lat;lng,lat;lng,lat;']
# ['device_ids' '设备id集合' 'varchar(200)' '保留字段，目前对应所有设备']
# 00000000000000000 200
# ['tag' '标签' 'varchar(50)' '保留字段']
# 00000000000000000 50
# ['status' '状态' 'TINYINT' '部门状态：\n1-有效；可用\n2-冻结：不可用，但有效\n3-无效：删除/过期']
# ['creator' '创建者' 'VARCHAR(100)' nan]
# 00000000000000000 100
# ['create_time' '创建时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['update_time' '更新时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['id' '自增id' 'int' '主键,自增长']
# ['start_time' '开始时间' 'varchar(50)' '格式: YYYY-MM-DD hh:mm:ss,联合索引']
# 00000000000000000 50
# ['task_id' '巡检任务id' 'int' '联合索引']
# ['device_id' '设备id' 'int' nan]
# ['task_run_status' '任务执行状态' 'varchar(50)' '任务执行状态']
# 00000000000000000 50
# ['failed_cause' '失败原因' 'varchar(50)' nan]
# 00000000000000000 50
# ['id' '自增id' 'int' '主键,自增长']
# ['start_date' '开始时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['table_name' '表名' 'varchar(50)' '界面使用的表名']
# 00000000000000000 50
# ['id' '自增id' 'int' '主键,自增长']
# ['task_id' '巡检任务id' 'int' nan]
# ['device_id' '设备id' 'int' nan]
# ['lng' '当前经度' 'double' nan]
# Error:['lng' '当前经度' 'double' nan]
# ['lat' '当前维度' 'double' nan]
# Error:['lat' '当前维度' 'double' nan]
# ['inspected_point_ids' '已巡逻点' 'longtext' '序号 逗号隔开']
# ['inspecting_point_ids' '未巡逻点' 'longtext' '序号 逗号隔开']
# ['id' '自增id' 'int' '主键,自增长']
# ['task_id' '巡检任务id' 'int' nan]
# ['device_id' '设备id' 'int' nan]
# ['lng' '当前经度' 'double' nan]
# Error:['lng' '当前经度' 'double' nan]
# ['lat' '当前维度' 'double' nan]
# Error:['lat' '当前维度' 'double' nan]
# ['inspected_point_ids' '已巡逻点' 'longtext' '序号 逗号隔开']
# ['inspecting_point_ids' '未巡逻点' 'longtext' '序号 逗号隔开']
# ['id' '巡检点id' 'int' '主键,自增长']
# ['point_name' '巡检点名称' 'varchar(50)' nan]
# 00000000000000000 50
# ['point_type' '巡检点类型' 'varchar(50)' 'sva,app']
# 00000000000000000 50
# ['lat' '维度' 'double' nan]
# Error:['lat' '维度' 'double' nan]
# ['lng' '经度' 'double' nan]
# Error:['lng' '经度' 'double' nan]
# ['tag' '标签' 'varchar(50)' '保留字段']
# 00000000000000000 50
# ['status' '状态' 'TINYINT' '状态：\n1-有效；可用\n2-冻结：不可用，但有效\n3-无效：删除/过期']
# ['creator' '创建者' 'VARCHAR(100)' nan]
# 00000000000000000 100
# ['create_time' '创建时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['update_time' '更新时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['id' '任务id' 'int' '主键,自增长']
# ['line_name' '线路名称' 'varchar(50)' nan]
# 00000000000000000 50
# ['line_points' '线路点' 'varchar(500)' '线路点以逗号隔开，顺序展开']
# 00000000000000000 500
# ['status' '状态' 'TINYINT' '部门状态：\n1-有效；可用\n2-冻结：不可用，但有效\n3-无效：删除/过期']
# ['creator' '创建者' 'VARCHAR(100)' nan]
# 00000000000000000 100
# ['create_time' '创建时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['update_time' '更新时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['id' '任务id' 'int' '主键,自增长']
# ['task_name' '任务名称' 'varchar(50)' nan]
# 00000000000000000 50
# ['device_id' '设备id' 'int' nan]
# ['task_line_id' '任务路线id' 'int' nan]
# ['task_begin_time' '任务开始时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['task_end_time' '任务结束时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['status' '状态' 'TINYINT' '部门状态：\n1-有效；可用\n2-冻结：不可用，但有效\n3-无效：删除/过期']
# ['creator' '创建者' 'VARCHAR(100)' nan]
# 00000000000000000 100
# ['create_time' '创建时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['update_time' '更新时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['id' '序号' 'int' ' NOT NULL AUTO_INCREMENT']
# ['start_time' '开始时间' 'datetime' nan]
# ['username' '用户名' 'varchar(100)' nan]
# 00000000000000000 100
# ['log_type' '日志类型' 'int' '1.登录\n2.查询\n3.操作']
# ['from_ip' '访问ip' 'varchar(100)' nan]
# 00000000000000000 100
# ['feature' '功能名称' 'varchar(100)' nan]
# 00000000000000000 100
# ['sub_feature' '子功能名称' 'varchar(100)' nan]
# 00000000000000000 100
# ['content' '日志内容' 'varchar(100)' nan]
# 00000000000000000 100
# ['log_time' '日志记录时间' 'datetime' nan]
# ['id' '自增id' 'int' '主键,自增长']
# ['device_id' '设备id' 'int' nan]
# ['user_id' '用户id' 'int' nan]
# ['time_span' '用户时段' 'varchar(50)' '目前保留 以后可能扩展用']
# 00000000000000000 50
# ['id' '设备id' 'int' '主键,自增长']
# ['device_no' '设备编号' 'varchar(50)' nan]
# 00000000000000000 50
# ['device_name' '设备名称' 'varchar(50)' nan]
# 00000000000000000 50
# ['msisdn' '手机号' 'varchar(50)' nan]
# 00000000000000000 50
# ['imsi' 'IMSI' 'varchar(50)' nan]
# 00000000000000000 50
# ['imei' 'IMEI' 'varchar(50)' nan]
# 00000000000000000 50
# ['remark' '备注' 'longtext' nan]
# ['status' '状态' 'TINYINT' '部门状态：\n1-有效；可用\n2-冻结：不可用，但有效\n3-无效：删除/过期']
# ['creator' '创建者' 'VARCHAR(100)' nan]
# 00000000000000000 100
# ['create_time' '创建时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['update_time' '更新时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['id' '部门id' 'int' '主键,自增长']
# ['department_name' '部门名称' 'varchar(50)' nan]
# 00000000000000000 50
# ['parent_name' '父级部门名称' 'varchar(50)' nan]
# 00000000000000000 50
# ['area' '地区' 'varchar(50)' nan]
# 00000000000000000 50
# ['status' '状态' 'TINYINT' '部门状态：\n1-有效；部门可用\n2-冻结：部门不可用，但有效\n3-无效：部门删除/过期']
# ['creator' '创建者' 'VARCHAR(100)' nan]
# 00000000000000000 100
# ['create_time' '创建时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['update_time' '更新时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['id' '功能id' 'int' '主键,自增长']
# ['fun_name' '功能名称' 'varchar(50)' nan]
# 00000000000000000 50
# ['parent_name' '父节点名称' 'varchar(50)' nan]
# 00000000000000000 50
# ['fun_group' '功能分组' 'varchar(50)' nan]
# 00000000000000000 50
# ['fun_url' '功能url' 'varchar(50)' nan]
# 00000000000000000 50
# ['img_url' '功能图标url' 'varchar(50)' nan]
# 00000000000000000 50
# ['status' '状态' 'TINYINT' '功能状态：\n1-有效；功能可用\n2-冻结：功能不可用，但有效\n3-无效：功能删除/过期']
# ['creator' '创建者' 'VARCHAR(100)' nan]
# 00000000000000000 100
# ['create_time' '创建时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['update_time' '更新时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['id' '角色id' 'int' '主键,自增长']
# ['name' '角色名称' 'VARCHAR(100)' nan]
# 00000000000000000 100
# ['use_authorize' '使用权限' 'longtext' nan]
# ['data_authorize' '数据使用权限' 'longtext' nan]
# ['data_create_authorize' '数据创建权限' 'longtext' nan]
# ['status' '状态' 'TINYINT' '角色状态：\n1-有效；角色可用\n2-冻结：角色不可用，但有效\n3-无效：角色删除/过期']
# ['creator' '创建者' 'VARCHAR(100)' nan]
# 00000000000000000 100
# ['create_time' '创建时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['update_time' '更新时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['id' '序号' 'int' '主键,自增长']
# ['user_id' '用户id' 'varchar(50)' '唯一']
# 00000000000000000 50
# ['user_name' '用户账号' 'varchar(50)' nan]
# 00000000000000000 50
# ['user_pwd' '用户密码' 'varchar(50)' 'md5加密']
# 00000000000000000 50
# ['real_name' '用户真实姓名' 'varchar(50)' nan]
# 00000000000000000 50
# ['msisdn' '用户电话号码' 'varchar(50)' nan]
# 00000000000000000 50
# ['email' '邮箱' 'varchar(50)' nan]
# 00000000000000000 50
# ['img_path' '照片路径' 'varchar(100)' nan]
# 00000000000000000 100
# ['role_id' '角色id' 'int' nan]
# ['department_id' '部门id' 'int' nan]
# ['status' '状态' 'TINYINT' '账户状态：\n1-有效；账户正常\n2-冻结：账户不可用，但有效\n3-无效：账户删除/过期']
# ['creator' '创建者' 'VARCHAR(100)' nan]
# 00000000000000000 100
# ['create_time' '创建时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# ['update_time' '更新时间' 'DATETIME NOT NULL DEFAULT NOW()'
#  '格式：YYYY-MM-DD hh:mm:ss']
# class (models.Model):
#     id = models.IntegerField(null=True)
#     start_time = models.CharField(max_length=50,null=True)
#     device_id = models.IntegerField(null=True)
#     lng = models.IntegerField(null=True)
#     lat = models.IntegerField(null=True)
#     warn_info = models.TextField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     start_date = models.DateTimeField(null=True)
#     table_name = models.CharField(max_length=50,null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     device_id = models.IntegerField(null=True)
#     lng = models.IntegerField(null=True)
#     lat = models.IntegerField(null=True)
#     warn_info = models.TextField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     device_id = models.IntegerField(null=True)
#     lng = models.IntegerField(null=True)
#     lat = models.IntegerField(null=True)
#     warn_info = models.TextField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     circle_name = models.CharField(max_length=50,null=True)
#     circle_points = models.TextField(null=True)
#     device_ids = models.CharField(max_length=200,null=True)
#     tag = models.CharField(max_length=50,null=True)
#     status = models.SmallIntegerField(null=True)
#     creator = models.CharField(max_length=100,null=True)
#     create_time = models.DateTimeField(null=True)
#     update_time = models.DateTimeField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     start_time = models.CharField(max_length=50,null=True)
#     task_id = models.IntegerField(null=True)
#     device_id = models.IntegerField(null=True)
#     task_run_status = models.CharField(max_length=50,null=True)
#     failed_cause = models.CharField(max_length=50,null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     start_date = models.DateTimeField(null=True)
#     table_name = models.CharField(max_length=50,null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     task_id = models.IntegerField(null=True)
#     device_id = models.IntegerField(null=True)
#     lng = models.IntegerField(null=True)
#     lat = models.IntegerField(null=True)
#     inspected_point_ids = models.TextField(null=True)
#     inspecting_point_ids = models.TextField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     task_id = models.IntegerField(null=True)
#     device_id = models.IntegerField(null=True)
#     lng = models.IntegerField(null=True)
#     lat = models.IntegerField(null=True)
#     inspected_point_ids = models.TextField(null=True)
#     inspecting_point_ids = models.TextField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     point_name = models.CharField(max_length=50,null=True)
#     point_type = models.CharField(max_length=50,null=True)
#     lat = models.CharField(max_length=50,null=True)
#     lng = models.CharField(max_length=50,null=True)
#     tag = models.CharField(max_length=50,null=True)
#     status = models.SmallIntegerField(null=True)
#     creator = models.CharField(max_length=100,null=True)
#     create_time = models.DateTimeField(null=True)
#     update_time = models.DateTimeField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     line_name = models.CharField(max_length=50,null=True)
#     line_points = models.CharField(max_length=500,null=True)
#     status = models.SmallIntegerField(null=True)
#     creator = models.CharField(max_length=100,null=True)
#     create_time = models.DateTimeField(null=True)
#     update_time = models.DateTimeField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     task_name = models.CharField(max_length=50,null=True)
#     device_id = models.IntegerField(null=True)
#     task_line_id = models.IntegerField(null=True)
#     task_begin_time = models.DateTimeField(null=True)
#     task_end_time = models.DateTimeField(null=True)
#     status = models.SmallIntegerField(null=True)
#     creator = models.CharField(max_length=100,null=True)
#     create_time = models.DateTimeField(null=True)
#     update_time = models.DateTimeField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     start_time = models.DateTimeField(null=True)
#     username = models.CharField(max_length=100,null=True)
#     log_type = models.IntegerField(null=True)
#     from_ip = models.CharField(max_length=100,null=True)
#     feature = models.CharField(max_length=100,null=True)
#     sub_feature = models.CharField(max_length=100,null=True)
#     content = models.CharField(max_length=100,null=True)
#     log_time = models.DateTimeField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     device_id = models.IntegerField(null=True)
#     user_id = models.IntegerField(null=True)
#     time_span = models.CharField(max_length=50,null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     device_no = models.CharField(max_length=50,null=True)
#     device_name = models.CharField(max_length=50,null=True)
#     msisdn = models.CharField(max_length=50,null=True)
#     imsi = models.CharField(max_length=50,null=True)
#     imei = models.CharField(max_length=50,null=True)
#     remark = models.TextField(null=True)
#     status = models.SmallIntegerField(null=True)
#     creator = models.CharField(max_length=100,null=True)
#     create_time = models.DateTimeField(null=True)
#     update_time = models.DateTimeField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     department_name = models.CharField(max_length=50,null=True)
#     parent_name = models.CharField(max_length=50,null=True)
#     area = models.CharField(max_length=50,null=True)
#     status = models.SmallIntegerField(null=True)
#     creator = models.CharField(max_length=100,null=True)
#     create_time = models.DateTimeField(null=True)
#     update_time = models.DateTimeField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     fun_name = models.CharField(max_length=50,null=True)
#     parent_name = models.CharField(max_length=50,null=True)
#     fun_group = models.CharField(max_length=50,null=True)
#     fun_url = models.CharField(max_length=50,null=True)
#     img_url = models.CharField(max_length=50,null=True)
#     status = models.SmallIntegerField(null=True)
#     creator = models.CharField(max_length=100,null=True)
#     create_time = models.DateTimeField(null=True)
#     update_time = models.DateTimeField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     name = models.CharField(max_length=100,null=True)
#     use_authorize = models.TextField(null=True)
#     data_authorize = models.TextField(null=True)
#     data_create_authorize = models.TextField(null=True)
#     status = models.SmallIntegerField(null=True)
#     creator = models.CharField(max_length=100,null=True)
#     create_time = models.DateTimeField(null=True)
#     update_time = models.DateTimeField(null=True)
#
#     class Meta:
#         db_table = ''
#
# class (models.Model):
#     id = models.IntegerField(null=True)
#     user_id = models.CharField(max_length=50,null=True)
#     user_name = models.CharField(max_length=50,null=True)
#     user_pwd = models.CharField(max_length=50,null=True)
#     real_name = models.CharField(max_length=50,null=True)
#     msisdn = models.CharField(max_length=50,null=True)
#     email = models.CharField(max_length=50,null=True)
#     img_path = models.CharField(max_length=100,null=True)
#     role_id = models.IntegerField(null=True)
#     department_id = models.IntegerField(null=True)
#     status = models.SmallIntegerField(null=True)
#     creator = models.CharField(max_length=100,null=True)
#     create_time = models.DateTimeField(null=True)
#     update_time = models.DateTimeField(null=True)
#
#     class Meta:
#         db_table = ''
